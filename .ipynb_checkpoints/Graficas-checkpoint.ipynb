# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('mejor_indiv.txt',sep=',', header = None)

# %%
df[:5]
# Out:
#        0         1         2         3   4
# 0  37.81  37.75422  37.79195  37.74071 NaN
# 1  37.81  37.75438  37.79093  37.74310  -1
# 2  37.81  37.75453  37.78992  37.74571  -1
# 3  37.81  37.75469  37.78890  37.74833  -1
# 4  37.80  37.75484  37.78788  37.75119  -1

# %%
df[[0,1,2,3]].plot();
df[[4]].plot();
plt.show()

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('estadisticos.txt',sep=',', header = None)

# %%
df[:5]
# Out:
#          0         1
# 0  0.00205  0.000006
# 1  0.00174  0.000008
# 2  0.00202  0.000008
# 3  0.00240  0.000008
# 4  0.00172  0.000005

# %%
df[[0]].plot();
plt.title('Promedio')
plt.ylim([0,0.003])
plt.grid(True)
df[[1]].plot();
plt.title('Desviacion')
plt.ylim([0,0.000015])
plt.grid(True)
plt.show()

# %% [markdown]
# #

# %%
#tarea
dims 100
indiv 100
sims 30 
iter 1000000

minimo 6 paginas por todos los articulos

Springer Lecture Notes in computer science
# Out:
#   File "<ipython-input-19-5d24e0da39e9>", line 2
#     dims 100
#            ^
# SyntaxError: invalid syntax
