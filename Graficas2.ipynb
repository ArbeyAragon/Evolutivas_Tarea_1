# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('mejor_indiv.txt',sep=',', header = None)

# %%
df[:5]
# Out:
#           0         1         2         3  4
# 0  37.70000  37.73567  37.72858  37.73550 -1
# 1  37.71000  37.73567  37.72703  37.73523 -1
# 2  37.70000  37.73557  37.72517  37.73490 -1
# 3  37.70000  37.73547  37.72357  37.73460 -1
# 4  37.72556  37.73538  37.72248  37.73444 -1

# %%
df[[0,1,2,3]].plot();
df[[4]].plot();
plt.show()

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('estadisticos.txt',sep=',', header = None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-67d572725db1> in <module>()
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 df = pd.read_csv('estadisticos.txt',sep=',', header = None)
#
# ...

# %%
df[:5]

# %%
df[[0]].plot();
plt.title('Promedio')
plt.ylim([0,0.003])
plt.grid(True)
df[[1]].plot();
plt.title('Desviacion')
plt.ylim([0,0.000015])
plt.grid(True)
plt.show()

# %%
#tarea
dims 100
indiv 100
sims 30 
iter 1000000

minimo 6 paginas por todos los articulos

Springer Lecture Notes in computer science
